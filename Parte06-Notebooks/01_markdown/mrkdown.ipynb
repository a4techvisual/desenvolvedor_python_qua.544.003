# %% [markdown]
# ## Checklist
#
# ### Linguagem de progrmação aceit em notebooks
#
# ✅ Python <br>
# ✅ Julia <br>
# ✅ R
#
#
# ### Linguagem que iremos utilizar no curso
#
# ✅ Python <br>
# ✅ Julia <br>
# ✅ R

# %% [markdown]
# # Título do seu documento
#
# Nesta aula iremos aprender sobre como inserir ***markodowns** dentro de arquivos do tipo **Jupyter Notbooks**.

# %% [markdown]
# ## Subtítulo de markdown
#
# O que diferencia um  markdown de um notebook, é que no caso do notebook, ele também é capaz de ler códigos da linguagem de programação *R*,julia, e é claro. *Python*.

# %% [markdown]
# >***Markodown*** é um tipo de documento muito usado em ciência de dafps e também para alimentar Inteligência Artificial.
# >Manipular este tipo de arquivo se torna fundamental para dominar as profissões do futuro que dependem de IAS.
